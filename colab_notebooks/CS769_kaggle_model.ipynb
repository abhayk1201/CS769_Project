# %%
# %cd /content/drive/MyDrive/CS769_Project/
# %pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/CS769_Project
# ...

# %%
# %cd /content/drive/MyDrive/CS769_Project/data/kagglesuicide
# !ls
# Out:
# /content/drive/MyDrive/CS769_Project/data/kagglesuicide
# labels.txt  Suicide_Detection.csv

# %%
from pandas import *
data = read_csv("Suicide_Detection.csv")
text = data['text'].tolist()
lbl = data['class'].tolist()

# %%
text[0:5]
print(len(text))
print(len(lbl))
# Out:
# 232074
# 232074

# %%
text_dev = text[0:2321]
text_tst = text[2322:4644]
text_trn = text[4645:]

lbl_dev = lbl[0:2321]
lbl_tst = lbl[2322:4644]
lbl_trn = lbl[4645:]

# %%
def compose(lst1, lst2):
  composed = []
  d = {'suicide': 1, 'non-suicide':2}
  for i in range(len(lst1)):
    new = [lst1[i], d[lst2[i]]]
    composed.append(new)
  return composed 

dev = compose(text_dev, lbl_dev)
trn = compose(text_trn, lbl_trn)
tst = compose(text_tst, lbl_tst)

# %%
fields = ['text', 'class']
with open('dev.tsv', 'w') as csvfile: 
    csvwriter = csv.writer(csvfile, delimiter='\t') 
    csvwriter.writerows(dev)

with open('trn.tsv', 'w') as csvfile: 
    csvwriter = csv.writer(csvfile, delimiter='\t') 
    csvwriter.writerows(trn)

with open('tst.tsv', 'w') as csvfile: 
    csvwriter = csv.writer(csvfile, delimiter='\t') 
    csvwriter.writerows(tst)

# %%
# !cd /content/drive/MyDrive/CS769_Project/
# !ls
# Out:
# ckpt	data_loader.py		  notebooks    requirements.txt  utils.py
# config	goemotions_classifier.py  __pycache__  setup.sh
# data	model.py		  README.md    tmp_bert

# %%
# !python3 goemotions_classifier.py --taxonomy kagglesuicide
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMultiLabelClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForMultiLabelClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMultiLabelClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# !python3 goemotions_classifier.py --taxonomy ekman
# Out:
# Downloading: 100% 208k/208k [00:00<00:00, 296kB/s]
# Downloading: 100% 182/182 [00:00<00:00, 178kB/s]
# Downloading: 100% 235/235 [00:00<00:00, 259kB/s]
# Downloading: 100% 766/766 [00:00<00:00, 786kB/s]
# Downloading: 100% 416M/416M [00:09<00:00, 45.2MB/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMultiLabelClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMultiLabelClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...
