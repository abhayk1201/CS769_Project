# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue May  3 07:02:44 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# cd /content/drive/MyDrive/769/assignment3

# %%
# cd /content/drive/MyDrive/769/assignment3
#!git clone https://github.com/Single430/Bert-Multi-Task.git
# Out:
# Cloning into 'Bert-Multi-Task'...
# remote: Enumerating objects: 58, done.
# remote: Total 58 (delta 0), reused 0 (delta 0), pack-reused 58
# Unpacking objects: 100% (58/58), done.

# %%
cd /content/drive/MyDrive/769/CS769_Project
# Out:
# /content/drive/MyDrive/769/CS769_Project

# %%
ls
# Out:
# ckpt/                     modeling.py       run_multi_task.py
# colab_notebooks/          model.py          run.sh
# config/                   multilabel.py     scripts/
# data/                     optimization.py   setup.sh
# data_loader.py            __pycache__/      tmp_bert/
# extract_features.py       README.md         tokenization.py
# github.txt                report.pdf        utils.py
# goemotions_classifier.py  requirements.txt

# %%
#!wget https://gist.github.com/W4ngatang/60c2bdb54d156a41194446737ce03e2e/raw/1502038877f6a88c225a34450793fbc3ea87eaba/download_glue_data.py

# %%
# !python download_glue_data.py

# %%
# !unzip uncased_L-12_H-768_A-12.zip

# %%
# Out:
# usage: convert_tf_checkpoint_to_pytorch.py [-h] --tf_checkpoint_path
#                                            TF_CHECKPOINT_PATH
#                                            --bert_config_file BERT_CONFIG_FILE
#                                            --pytorch_dump_path
#                                            PYTORCH_DUMP_PATH
# convert_tf_checkpoint_to_pytorch.py: error: the following arguments are required: --tf_checkpoint_path, --bert_config_file, --pytorch_dump_path

# %%
ls
# Out:
#  configs/                              README.md
#  convert_tf_checkpoint_to_pytorch.py   run_multi_task.py
#  extract_features.py                   tokenization.py
#  glue_data/                            uncased_L-12_H-768_A-12/
#  modeling.py                          'uncased_L-12_H-768_A-12 copy.zip'
#  optimization.py                       uncased_L-12_H-768_A-12.zip

# %% [markdown]
# # Multi-class /Hierarchial taxonomy tasks in MTL setting

# %%
# !python run_multi_task.py \
  --seed 42 \
  --output_dir ./ckpt/MTL_goemotion_orig_ekman \
  --tasks goemotion_taxonomy \
  --sample 'anneal'\
  --multi \
  --do_train \
  --do_eval \
  --do_lower_case \
  --data_dir ./data/ \
  --vocab_file ./ckpt/uncased_L-12_H-768_A-12/vocab.txt \
  --bert_config_file ./config/MTL_pals_config.json \
  --init_checkpoint ./ckpt/uncased_L-12_H-768_A-12/pytorch_model.bin \
  --max_seq_length 50 \
  --train_batch_size 32 \
  --learning_rate 2e-5 \
  --num_train_epochs 10 \
  --gradient_accumulation_steps 1
# Out:
# 05/03/2022 07:34:52 - INFO - __main__ -   device cuda n_gpu 1 distributed training False
# 05/03/2022 07:35:11 - INFO - __main__ -     Num Tasks = 2
# 05/03/2022 07:35:17 - INFO - __main__ -   ***** training data for goemotion_original *****
# 05/03/2022 07:35:17 - INFO - __main__ -     Data size = 36307
# 05/03/2022 07:35:24 - INFO - __main__ -   ***** training data for goemotion_ekman *****
# 05/03/2022 07:35:24 - INFO - __main__ -     Data size = 39554
# 05/03/2022 07:35:24 - INFO - __main__ -     Num param = 113148827
# Epoch:   0% 0/10 [00:00<?, ?it/s]05/03/2022 07:35:25 - INFO - __main__ -   Task: 0, Step: 0
# 05/03/2022 07:35:25 - INFO - __main__ -   Loss: 3.458298683166504
# /content/drive/MyDrive/769/CS769_Project/optimization.py:159: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python run_multi_task.py \
  --seed 42 \
  --output_dir ./ckpt/MTL_goemotion_orig_ekman_prop \
  --tasks goemotion_taxonomy \
  --sample 'prop'\
  --multi \
  --do_train \
  --do_eval \
  --do_lower_case \
  --data_dir ./data/ \
  --vocab_file ./ckpt/uncased_L-12_H-768_A-12/vocab.txt \
  --bert_config_file ./config/MTL_pals_config.json \
  --init_checkpoint ./ckpt/uncased_L-12_H-768_A-12/pytorch_model.bin \
  --max_seq_length 50 \
  --train_batch_size 32 \
  --learning_rate 2e-5 \
  --num_train_epochs 10 \
  --gradient_accumulation_steps 1
# Out:
# 05/03/2022 08:11:33 - INFO - __main__ -   device cuda n_gpu 1 distributed training False
# 05/03/2022 08:11:41 - INFO - __main__ -     Num Tasks = 2
# 05/03/2022 08:11:47 - INFO - __main__ -   ***** training data for goemotion_original *****
# 05/03/2022 08:11:47 - INFO - __main__ -     Data size = 36307
# 05/03/2022 08:11:54 - INFO - __main__ -   ***** training data for goemotion_ekman *****
# 05/03/2022 08:11:54 - INFO - __main__ -     Data size = 39554
# 05/03/2022 08:11:54 - INFO - __main__ -     Num param = 113148827
# Epoch:   0% 0/10 [00:00<?, ?it/s]05/03/2022 08:11:55 - INFO - __main__ -   Task: 0, Step: 0
# 05/03/2022 08:11:55 - INFO - __main__ -   Loss: 3.458298683166504
# /content/drive/MyDrive/769/CS769_Project/optimization.py:159: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python run_multi_task.py \
  --seed 42 \
  --output_dir ./ckpt/MTL_goemotion_orig_ekman_sqrt \
  --tasks goemotion_taxonomy \
  --sample 'sqrt'\
  --multi \
  --do_train \
  --do_eval \
  --do_lower_case \
  --data_dir ./data/ \
  --vocab_file ./ckpt/uncased_L-12_H-768_A-12/vocab.txt \
  --bert_config_file ./config/MTL_pals_config.json \
  --init_checkpoint ./ckpt/uncased_L-12_H-768_A-12/pytorch_model.bin \
  --max_seq_length 50 \
  --train_batch_size 32 \
  --learning_rate 2e-5 \
  --num_train_epochs 10 \
  --gradient_accumulation_steps 1
# Out:
# 05/03/2022 08:56:29 - INFO - __main__ -   device cuda n_gpu 1 distributed training False
# 05/03/2022 08:56:36 - INFO - __main__ -     Num Tasks = 2
# 05/03/2022 08:56:43 - INFO - __main__ -   ***** training data for goemotion_original *****
# 05/03/2022 08:56:43 - INFO - __main__ -     Data size = 36307
# 05/03/2022 08:56:50 - INFO - __main__ -   ***** training data for goemotion_ekman *****
# 05/03/2022 08:56:50 - INFO - __main__ -     Data size = 39554
# 05/03/2022 08:56:50 - INFO - __main__ -     Num param = 113148827
# Epoch:   0% 0/10 [00:00<?, ?it/s]05/03/2022 08:56:50 - INFO - __main__ -   Task: 0, Step: 0
# 05/03/2022 08:56:50 - INFO - __main__ -   Loss: 3.458298683166504
# /content/drive/MyDrive/769/CS769_Project/optimization.py:159: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %% [markdown]
# # Twitter sentiment and Goemotions in MTL settings

# %%
# !python run_multi_task.py \
  --seed 42 \
  --output_dir ./ckpt/MTL_goemotion_twitter \
  --tasks goemotion_twitter_sentiment \
  --sample 'anneal'\
  --multi \
  --do_train \
  --do_eval \
  --do_lower_case \
  --data_dir ./data/ \
  --vocab_file ./ckpt/uncased_L-12_H-768_A-12/vocab.txt \
  --bert_config_file ./config/MTL_pals_config.json \
  --init_checkpoint ./ckpt/uncased_L-12_H-768_A-12/pytorch_model.bin \
  --max_seq_length 50 \
  --train_batch_size 32 \
  --learning_rate 2e-5 \
  --num_train_epochs 10 \
  --gradient_accumulation_steps 1
# Out:
# 05/03/2022 10:23:40 - INFO - __main__ -   device cuda n_gpu 1 distributed training False
# 05/03/2022 10:23:53 - INFO - __main__ -     Num Tasks = 2
# 05/03/2022 10:24:00 - INFO - __main__ -   ***** training data for goemotion_original *****
# 05/03/2022 10:24:00 - INFO - __main__ -     Data size = 36307
# 05/03/2022 10:29:07 - INFO - __main__ -   ***** training data for twitter_sentiment *****
# 05/03/2022 10:29:07 - INFO - __main__ -     Data size = 1599999
# 05/03/2022 10:29:13 - INFO - __main__ -     Num param = 113144982
# Epoch:   0% 0/10 [00:00<?, ?it/s]05/03/2022 10:29:14 - INFO - __main__ -   Task: 0, Step: 0
# 05/03/2022 10:29:14 - INFO - __main__ -   Loss: 3.7439968585968018
# /content/drive/MyDrive/769/CS769_Project/optimization.py:159: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python run_multi_task.py \
  --seed 42 \
  --output_dir ./ckpt/MTL_goemotion_twitter_prop \
  --tasks goemotion_twitter_sentiment \
  --sample 'prop'\
  --multi \
  --do_train \
  --do_eval \
  --do_lower_case \
  --data_dir ./data/ \
  --vocab_file ./ckpt/uncased_L-12_H-768_A-12/vocab.txt \
  --bert_config_file ./config/MTL_pals_config.json \
  --init_checkpoint ./ckpt/uncased_L-12_H-768_A-12/pytorch_model.bin \
  --max_seq_length 50 \
  --train_batch_size 32 \
  --learning_rate 2e-5 \
  --num_train_epochs 10 \
  --gradient_accumulation_steps 1
# Out:
# 05/03/2022 10:58:16 - INFO - __main__ -   device cuda n_gpu 1 distributed training False
# 05/03/2022 10:58:29 - INFO - __main__ -     Num Tasks = 2
# 05/03/2022 10:58:35 - INFO - __main__ -   ***** training data for goemotion_original *****
# 05/03/2022 10:58:35 - INFO - __main__ -     Data size = 36307
# 05/03/2022 11:03:42 - INFO - __main__ -   ***** training data for twitter_sentiment *****
# 05/03/2022 11:03:42 - INFO - __main__ -     Data size = 1599999
# 05/03/2022 11:03:48 - INFO - __main__ -     Num param = 113144982
# Epoch:   0% 0/10 [00:00<?, ?it/s]05/03/2022 11:03:48 - INFO - __main__ -   Task: 0, Step: 0
# 05/03/2022 11:03:48 - INFO - __main__ -   Loss: 3.7439968585968018
# /content/drive/MyDrive/769/CS769_Project/optimization.py:159: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %%
# !python run_multi_task.py \
  --seed 42 \
  --output_dir ./ckpt/MTL_goemotion_twitter_sqrt \
  --tasks goemotion_twitter_sentiment \
  --sample 'sqrt'\
  --multi \
  --do_train \
  --do_eval \
  --do_lower_case \
  --data_dir ./data/ \
  --vocab_file ./ckpt/uncased_L-12_H-768_A-12/vocab.txt \
  --bert_config_file ./config/MTL_pals_config.json \
  --init_checkpoint ./ckpt/uncased_L-12_H-768_A-12/pytorch_model.bin \
  --max_seq_length 50 \
  --train_batch_size 32 \
  --learning_rate 2e-5 \
  --num_train_epochs 10 \
  --gradient_accumulation_steps 1
# Out:
# 05/03/2022 11:32:34 - INFO - __main__ -   device cuda n_gpu 1 distributed training False
# 05/03/2022 11:32:47 - INFO - __main__ -     Num Tasks = 2
# 05/03/2022 11:32:53 - INFO - __main__ -   ***** training data for goemotion_original *****
# 05/03/2022 11:32:53 - INFO - __main__ -     Data size = 36307
# 05/03/2022 11:37:55 - INFO - __main__ -   ***** training data for twitter_sentiment *****
# 05/03/2022 11:37:55 - INFO - __main__ -     Data size = 1599999
# 05/03/2022 11:38:01 - INFO - __main__ -     Num param = 113144982
# Epoch:   0% 0/10 [00:00<?, ?it/s]05/03/2022 11:38:01 - INFO - __main__ -   Task: 0, Step: 0
# 05/03/2022 11:38:01 - INFO - __main__ -   Loss: 3.7439968585968018
# /content/drive/MyDrive/769/CS769_Project/optimization.py:159: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %% [markdown]
# **SINGLE TASK**

# %%
# !python run_multi_task.py \
  --seed 42 \
  --output_dir ./ckpt/goemotion_ekman \
  --tasks single \
  --task_id 2 \
  --sample 'rr'\
  --multi \
  --do_train \
  --do_eval \
  --do_lower_case \
  --data_dir ./data/ \
  --vocab_file ./ckpt/uncased_L-12_H-768_A-12/vocab.txt \
  --bert_config_file ./config/MTL_pals_config.json \
  --init_checkpoint ./ckpt/uncased_L-12_H-768_A-12/pytorch_model.bin \
  --max_seq_length 50 \
  --train_batch_size 32 \
  --learning_rate 2e-5 \
  --num_train_epochs 10 \
  --gradient_accumulation_steps 1
# Out:
# 05/03/2022 12:09:37 - INFO - __main__ -   device cuda n_gpu 1 distributed training False
# 05/03/2022 12:09:43 - INFO - __main__ -     Num Tasks = 1
# 05/03/2022 12:09:50 - INFO - __main__ -   ***** training data for goemotion_ekman *****
# 05/03/2022 12:09:50 - INFO - __main__ -     Data size = 39554
# 05/03/2022 12:09:50 - INFO - __main__ -     Num param = 111307459
# Epoch:   0% 0/10 [00:00<?, ?it/s]05/03/2022 12:09:50 - INFO - __main__ -   Task: 0, Step: 0
# 05/03/2022 12:09:50 - INFO - __main__ -   Loss: 1.9757914543151855
# /content/drive/MyDrive/769/CS769_Project/optimization.py:159: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1055.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# 05/03/2022 12:12:43 - INFO - __main__ -   ***** Eval results *****
# ...

# %%
# !python run_multi_task.py \
  --seed 42 \
  --output_dir ./ckpt/twitter_sentiment \
  --tasks single \
  --task_id 3 \
  --sample 'rr'\
  --multi \
  --do_train \
  --do_eval \
  --do_lower_case \
  --data_dir ./data/ \
  --vocab_file ./ckpt/uncased_L-12_H-768_A-12/vocab.txt \
  --bert_config_file ./config/MTL_pals_config.json \
  --init_checkpoint ./ckpt/uncased_L-12_H-768_A-12/pytorch_model.bin \
  --max_seq_length 50 \
  --train_batch_size 32 \
  --learning_rate 2e-5 \
  --num_train_epochs 10 \
  --gradient_accumulation_steps 1
# Out:
# 05/03/2022 12:38:43 - INFO - __main__ -   device cuda n_gpu 1 distributed training False
# 05/03/2022 12:38:55 - INFO - __main__ -     Num Tasks = 1
# 05/03/2022 12:44:00 - INFO - __main__ -   ***** training data for twitter_sentiment *****
# 05/03/2022 12:44:00 - INFO - __main__ -     Data size = 1599999
# 05/03/2022 12:44:06 - INFO - __main__ -     Num param = 111303614
# Epoch:   0% 0/10 [00:00<?, ?it/s]05/03/2022 12:44:06 - INFO - __main__ -   Task: 0, Step: 0
# 05/03/2022 12:44:06 - INFO - __main__ -   Loss: 0.6775206923484802
# /content/drive/MyDrive/769/CS769_Project/optimization.py:159: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1055.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# 05/03/2022 12:48:29 - INFO - __main__ -   Task: 0, Step: 1000
# ...

# %%
# previous runs

# %%
# !python run_multi_task.py \
  --seed 42 \
  --output_dir /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/Tmp_Model/goemotion \
  --tasks single \
  --task_id 1 \
  --sample 'rr'\
  --multi \
  --do_train \
  --do_eval \
  --do_lower_case \
  --data_dir /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/data/ \
  --vocab_file /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/uncased_L-12_H-768_A-12/vocab.txt \
  --bert_config_file /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/config/pals_config.json \
  --init_checkpoint /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/uncased_L-12_H-768_A-12/pytorch_model.bin \
  --max_seq_length 50 \
  --train_batch_size 32 \
  --learning_rate 2e-5 \
  --num_train_epochs 10 \
  --gradient_accumulation_steps 1
# Out:
# 04/09/2022 04:35:58 - INFO - __main__ -   device cuda n_gpu 1 distributed training False
# 04/09/2022 04:36:06 - INFO - __main__ -     Num Tasks = 1
# 04/09/2022 04:36:14 - INFO - __main__ -   ***** training data for goemotion *****
# 04/09/2022 04:36:14 - INFO - __main__ -     Data size = 36307
# 04/09/2022 04:36:14 - INFO - __main__ -     Num param = 111323608
# Epoch:   0% 0/10 [00:00<?, ?it/s]04/09/2022 04:36:15 - INFO - __main__ -   Task: 0, Step: 0
# 04/09/2022 04:36:15 - INFO - __main__ -   Loss: 3.2078166007995605
# /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/optimization.py:154: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1050.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# 04/09/2022 04:39:27 - INFO - __main__ -   ***** Eval results *****
# ...

# %%
# !python run_multi_task.py \
  --seed 42 \
  --output_dir /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/Tmp_Model/sst \
  --tasks single \
  --task_id 0 \
  --sample 'rr'\
  --multi \
  --do_train \
  --do_eval \
  --do_lower_case \
  --data_dir /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/data/ \
  --vocab_file /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/uncased_L-12_H-768_A-12/vocab.txt \
  --bert_config_file /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/config/pals_config.json \
  --init_checkpoint /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/uncased_L-12_H-768_A-12/pytorch_model.bin \
  --max_seq_length 50 \
  --train_batch_size 32 \
  --learning_rate 2e-5 \
  --num_train_epochs 10 \
  --gradient_accumulation_steps 1
# Out:
# 04/09/2022 07:39:23 - INFO - __main__ -   device cuda n_gpu 1 distributed training False
# 04/09/2022 07:39:30 - INFO - __main__ -     Num Tasks = 1
# 04/09/2022 07:39:42 - INFO - __main__ -   ***** training data for sst *****
# 04/09/2022 07:39:42 - INFO - __main__ -     Data size = 67349
# 04/09/2022 07:39:42 - INFO - __main__ -     Num param = 111303614
# Epoch:   0% 0/10 [00:00<?, ?it/s]04/09/2022 07:39:42 - INFO - __main__ -   Task: 0, Step: 0
# 04/09/2022 07:39:42 - INFO - __main__ -   Loss: 0.679380476474762
# /content/drive/MyDrive/769/assignment3/Bert-Multi-Task2/optimization.py:159: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1050.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# 04/09/2022 07:45:00 - INFO - __main__ -   Task: 0, Step: 1000
# ...
